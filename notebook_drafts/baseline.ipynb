# %% [markdown]
# # 0. Configuration

# %%
# links to shared data MovieLens
# source on kaggle: https://www.kaggle.com/code/quangnhatbui/movie-recommender/data
RATINGS_SMALL_URL = 'https://drive.google.com/file/d/1BlZfCLLs5A13tbNSJZ1GPkHLWQOnPlE4/view?usp=share_link'
MOVIES_METADATA_URL = 'https://drive.google.com/file/d/19g6-apYbZb5D-wRj4L7aYKhxS-fDM4Fb/view?usp=share_link'

# %% [markdown]
# # 1. Modules and functions

# %%
import numpy as np
import pandas as pd

from itertools import islice, cycle, product

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. 1. Helper functions to avoid copy paste

# %%
def read_csv_from_gdrive(url):
    """
    gets csv data from a given url (taken from file -> share -> copy link)
    :url: example https://drive.google.com/file/d/1BlZfCLLs5A13tbNSJZ1GPkHLWQOnPlE4/view?usp=share_link
    """
    file_id = url.split('/')[-2]
    file_path = 'https://drive.google.com/uc?export=download&id=' + file_id
    data = pd.read_csv(file_path)

    return data

# %%
def compute_popularity(df: pd.DataFrame, item_id: str, max_candidates: int):
    """
    calculates mean rating to define popular titles
    """
    popular_titles = df.groupby(item_id).agg({'rating': np.mean})\
                     .sort_values(['rating'], ascending=False).head(max_candidates).index.values

    return popular_titles

# %% [markdown]
# # 2. Data

# %% [markdown]
# ## 2. 1. Load data

# %% [markdown]
# `interactions` dataset shows list of movies that users watched, along with given ratings:

# %%
# interactions data
interactions = read_csv_from_gdrive(RATINGS_SMALL_URL)
interactions.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# `movies_metadata` dataset shows the list of movies existing on OKKO platform:

# %%
# information about films etc
movies_metadata = read_csv_from_gdrive(MOVIES_METADATA_URL)
movies_metadata.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 2.2 Data preparation

# %% [markdown]
# The objective of this step is to identify movies from two datasets that were watched by users.

# %%
interactions.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
movies_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
# align data in both dataframes to merge
interactions['movieId'] = interactions['movieId'].astype(str)
movies_metadata.rename(columns = {'id': 'movieId'}, inplace = True)

# %%
# leave only those films that intersect with each other
interactions_filtered = interactions.loc[interactions['movieId'].isin(movies_metadata['movieId'])]
print(interactions.shape, interactions_filtered.shape)
# Out:
# (100004, 4) (44989, 4)

# %% [markdown]
# *-- explain why we need a mapper?*

# %%
# crate mapper for movieId and title names
item_name_mapper = dict(zip(movies_metadata['movieId'], movies_metadata['original_title']))

# %%
item_name_mapper
# Out:
# {'862': 'Toy Story',
#  '8844': 'Jumanji',
#  '15602': 'Grumpier Old Men',
#  '31357': 'Waiting to Exhale',
#  '11862': 'Father of the Bride Part II',
#  '949': 'Heat',
#  '11860': 'Sabrina',
#  '45325': 'Tom and Huck',
#  '9091': 'Sudden Death',
#  '710': 'GoldenEye',
#  '9087': 'The American President',
#  '12110': 'Dracula: Dead and Loving It',
#  '21032': 'Balto',
#  '10858': 'Nixon',
#  '1408': 'Cutthroat Island',
#  '524': 'Casino',
#  '4584': 'Sense and Sensibility',
#  '5': 'Four Rooms',
#  '9273': 'Ace Ventura: When Nature Calls',
#  '11517': 'Money Train',
#  '8012': 'Get Shorty',
#  '1710': 'Copycat',
#  '9691': 'Assassins',
#  '12665': 'Powder',
#  '451': 'Leaving Las Vegas',
#  '16420': 'Othello',
#  '9263': 'Now and Then',
#  '17015': 'Persuasion',
#  '902': 'La Cité des Enfants Perdus',
#  '37557': '摇啊摇，摇到外婆桥',
#  '9909': 'Dangerous Minds',
#  '63': 'Twelve Monkeys',
#  '78802': 'Guillaumet, les ailes du courage',
#  '9598': 'Babe',
#  '47018': 'Carrington',
#  '687': 'Dead Man Walking',
#  '139405': 'Across the Sea of Time',
#  '33689': 'It Takes Two',
#  '9603': 'Clueless',
#  '34615': 'Cry, the Beloved Country',
#  '31174': 'Richard III',
#  '11443': 'Dead Presidents',
#  '35196': 'Restoration',
#  '9312': 'Mortal Kombat',
#  '577': 'To Die For',
#  '11861': 'How To Make An American Quilt',
#  '807': 'Se7en',
#  '10530': 'Pocahontas',
#  '8391': 'When Night Is Falling',
#  '629': 'The Usual Suspects',
#  '117164': 'Guardian Angel',
#  '11448': 'Mighty Aphrodite',
#  '49133': 'Lamerica',
#  '26441': 'The Big Green',
#  '97406': 'Georgia',
#  '124057': 'Kids of the Round Table',
#  '9089': 'Home for the Holidays',
#  '11010': 'Il postino',
#  '99040': 'Le confessionnal',
#  '11359': 'The Indian in the Cupboard',
#  '17182': 'Eye for an Eye',
#  '2054': "Mr. Holland's Opus",
#  '10607': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#  '19760': 'Two If by Sea',
#  '9536': 'Bio-Dome',
#  '11525': 'Lawnmower Man 2: Beyond Cyberspace',
#  '40628': 'Two Bits',
#  '4482': 'Gazon maudit',
#  '10634': 'Friday',
#  '755': 'From Dusk Till Dawn',
#  '11859': 'Fair Game',
#  '28387': 'Kicking and Screaming',
#  '48750': 'Les misérables',
#  '20927': 'Bed of Roses',
#  '36929': 'Big Bully',
#  '9102': 'Screamers',
#  '124626': 'Nico Icon',
#  '27526': 'The Crossing Guard',
#  '9623': 'The Juror',
#  '46785': 'بادکنک سفید',
#  '400': "Things to Do in Denver When You're Dead",
#  '880': 'Antonia',
#  '146599': 'Once Upon a Time... When We Were Colored',
#  '188588': 'Last Summer in the Hamptons',
#  '8447': 'Angels and Insects',
#  '10534': 'White Squall',
#  '17414': 'Dunston Checks In',
#  '13997': 'Black Sheep',
#  '2086': 'Nick of Time',
#  '61548': 'The Journey of August King',
#  '9095': 'Mary Reilly',
#  '12158': 'Vampire in Brooklyn',
#  '9283': 'Beautiful Girls',
#  '9208': 'Broken Arrow',
#  '40154': "A Midwinter's Tale",
#  '406': 'La Haine',
#  '45549': 'Shopping',
#  '63076': 'Heidi Fleiss: Hollywood Madam',
#  '11062': 'City Hall',
#  '13685': 'Bottle Rocket',
#  '47475': 'Mr. Wrong',
#  '2045': 'Unforgettable',
#  '9614': 'Happy Gilmore',
#  '688': 'The Bridges of Madison County',
#  '11907': 'Keiner liebt mich',
#  '10874': 'Muppet Treasure Island',
#  '89333': 'Catwalk',
#  '96357': 'Headless Body in Topless Bar',
#  '197': 'Braveheart',
#  '103': 'Taxi Driver',
#  '33542': '紅番區',
#  '43566': 'Before and After',
#  '71754': "Margaret's Museum",
#  '43612': 'Le Bonheur est dans le pré',
#  '51352': 'Anne Frank Remembered',
#  '16934': "The Young Poisoner's Handbook",
#  '10324': 'If Lucy Fell',
#  '78406': 'Steal Big Steal Little',
#  '55731': 'Race the Sun',
#  '32119': 'The Boys of St. Vincent',
#  '11066': 'Boomerang',
#  '11104': '重慶森林',
#  '37975': "L'uomo delle stelle",
#  '2074': 'Flirting with Disaster',
#  '27793': 'The NeverEnding Story III',
#  '44284': 'صمت القصور',
#  '290157': "Jupiter's Wife",
#  '110972': 'Pie in the Sky',
#  '32622': 'Angela',
#  '73067': 'Frankie Starlight',
#  '11863': 'Jade',
#  '55475': 'Nueba Yol',
#  '124636': 'Sonic Outlaws',
#  '9101': 'Down Periscope',
#  '123360': 'From the Journals of Jean Seberg',
#  '5757': 'Man of the Year',
#  '39428': 'The Neon Bible',
#  '124639': 'Target',
#  '9302': 'Up Close & Personal',
#  '11000': 'The Birdcage',
#  '249882': 'Gospa',
#  '16388': 'The Brothers McMullen',
#  '9737': 'Bad Boys',
#  '30765': 'The Amazing Panda Adventure',
#  '10474': 'The Basketball Diaries',
#  '22279': 'An Awfully Big Adventure',
#  '30157': 'Amateur',
#  '568': 'Apollo 13',
#  '11780': 'Rob Roy',
#  '34996': 'The Addiction',
#  '414': 'Batman Forever',
#  '649': 'Belle de jour',
#  '1873': 'Beyond Rangoon',
#  '5894': 'Blue in the Face',
#  '1775': 'Canadian Bacon',
#  '8839': 'Casper',
#  '20649': 'Clockers',
#  '10329': 'Congo',
#  '8963': 'Crimson Tide',
#  '26564': 'Crumb',
#  '8068': 'Desperado',
#  '8512': 'Devil in a Blue Dress',
#  '1572': 'Die Hard: With a Vengeance',
#  '13552': 'The Doom Generation',
#  '259209': 'Feast of July',
#  '6520': 'First Knight',
#  '9073': 'Free Willy 2 - The Adventure Home',
#  '10428': 'Hackers',
#  '17447': 'Jeffrey',
#  '9886': 'Johnny Mnemonic',
#  '9482': 'Judge Dredd',
#  '19326': 'Jury Duty',
#  '9344': 'Kids',
#  '9071': 'Living in Oblivion',
#  '8973': 'Lord of Illusions',
#  '15730': 'Love & Human Remains',
#  '47608': 'Mad Love',
#  '2293': 'Mallrats',
#  '9070': 'Mighty Morphin Power Rangers: The Movie',
#  '68274': 'Moonlight and Valentino',
#  '48787': 'Mute Witness',
#  '34574': 'Nadja',
#  '1642': 'The Net',
#  '11472': 'Nine Months',
#  '36196': 'Party Girl',
#  '11980': 'The Prophecy',
#  '58372': 'Reckless',
#  '32646': 'Safe',
#  '10533': 'The Scarlet Letter',
#  '56088': 'The Show',
#  '10802': 'Showgirls',
#  '10149': 'Smoke',
#  '18402': 'Something to Talk About',
#  '9348': 'Species',
#  '139408': 'The Stars Fell on Henrietta',
#  '281': 'Strange Days',
#  '5967': 'Les parapluies de Cherbourg',
#  '79593': 'The Tie That Binds',
#  '47939': 'Three Wishes',
#  '36834': 'Total Eclipse',
#  '9090': 'To Wong Foo, Thanks for Everything! Julie Newmar',
#  '3512': 'Under Siege 2: Dark Territory',
#  '52856': 'Unstrung Heroes',
#  '77350': 'Unzipped',
#  '9560': 'A Walk in the Clouds',
#  '9804': 'Waterworld',
#  '31611': "White Man's Burden",
#  '65796': 'Wild Bill',
#  '49805': 'The Browning Version',
#  '26258': 'Bushwhacked',
#  '50797': 'Утомлённые солнцем',
#  '19155': 'Before the Rain',
#  '76': 'Before Sunrise',
#  '11017': 'Billy Madison',
#  '37141': 'The Babysitter',
#  '9382': 'Boys on the Side',
#  '6715': 'The Cure',
#  '18256': 'Castle Freak',
#  '22625': 'Circle of Friends',
#  '2292': 'Clerks',
#  '1909': 'Don Juan DeMarco',
#  '8984': 'Disclosure',
#  '61813': 'Dream Man',
#  '4954': 'Drop Zone',
#  '62488': 'Destiny Turns on the Radio',
#  '10531': 'Death and the Maiden',
#  '11929': 'Dolores Claiborne',
#  '8467': 'Dumb and Dumber',
#  '10451': '飲食男女',
#  '20156': 'Exotica',
#  '18395': 'Exit to Eden',
#  '522': 'Ed Wood',
#  '397': 'French Kiss',
#  '10525': 'Forget Paris',
#  '27985': 'Far from Home: The Adventures of Yellow Dog',
#  '15789': 'A Goofy Movie',
#  '27303': 'Hideaway',
#  '21183': 'Fluke',
#  '10954': 'Farinelli',
#  '47867': 'Gordy',
#  '43475': 'Gumby: The Movie',
#  '72031': 'The Glass Shield',
#  '14275': 'Hoop Dreams',
#  '1024': 'Heavenly Creatures',
#  '17207': 'Houseguest',
#  '13701': 'Immortal Beloved',
#  '14819': 'Heavyweights',
#  '32631': 'The Hunted',
#  '11777': 'I.Q.',
#  '628': 'Interview with the Vampire',
#  '87729': 'Jefferson in Paris',
#  '18713': 'The Jerky Boys',
#  '6280': 'Junior',
#  '9061': 'Just Cause',
#  '37108': "A Kid in King Arthur's Court",
#  '6071': 'Kiss of Death',
#  '11': 'Star Wars',
#  '9587': 'Little Women',
#  '19101': 'A Little Princess',
#  '49980': 'Ladybird Ladybird',
#  '17961': "L'Enfer",
#  '18183': 'Como agua para chocolate',
#  '4476': 'Legends of the Fall',
#  '11008': 'Major Payne',
#  '47504': 'Little Odessa',
#  '32325': 'Mi Vida Loca',
#  '43742': 'Love Affair',
#  '28313': 'Losing Isaiah',
#  '11318': 'The Madness of King George',
#  '3036': 'Frankenstein',
#  '40490': 'Man of the House',
#  '24070': 'Mixed Nuts',
#  '8986': 'Milk Money',
#  '10510': 'Miracle on 34th Street',
#  '17402': 'Miami Rhapsody',
#  '38722': 'My Family',
#  '8438': 'Murder in the First',
#  '11593': "Nobody's Fool",
#  '1945': 'Nell',
#  '39310': 'New Jersey Drive',
#  '109560': 'New York Cop',
#  '56428': 'Beyond Bedlam',
#  '63105': 'Nemesis 2 - Nebula',
#  '131957': 'Nina Takes a Lover',
#  '241': 'Natural Born Killers',
#  '9058': 'Only You',
#  '527': 'Once Were Warriors',
#  '18220': 'Poison Ivy II: Lily',
#  '6950': 'Outbreak',
#  '101': 'Léon',
#  '63020': 'The Perez Family',
#  '2307': "A Pyromaniac's Love Story",
#  '680': 'Pulp Fiction',
#  '41478': 'Panther',
#  '25296': 'Pushing Hands',
#  '40156': 'Priest',
#  '11450': 'Quiz Show',
#  '30304': 'Picture Bride',
#  '10452': 'La Reine Margot',
#  '12106': 'The Quick and the Dead',
#  '161495': 'Roommates',
#  '3586': 'Prêt-à-Porter',
#  '110': 'Trois couleurs : Rouge',
#  '108': 'Trois couleurs : Bleu',
#  '109': 'Trois couleurs : Blanc',
#  '159185': 'Pao Da Shuang Deng',
#  '36357': 'Rent-a-Kid',
#  '92769': 'Relative Fear',
#  '28033': 'Stuart Saves His Family',
#  '22586': 'The Swan Princess',
#  '14334': 'The Secret of Roan Inish',
#  '2636': 'The Specialist',
#  '2164': 'Stargate',
#  '11395': 'The Santa Clause',
#  '278': 'The Shawshank Redemption',
#  '9905': 'Shallow Grave',
#  '87078': 'Suture',
#  '12527': 'Fresa y chocolate',
#  '20306': 'Swimming with Sharks',
#  '36614': 'The Sum of Us',
#  '27993': 'Senior Trip',
#  '31439': '活着',
#  '9067': 'Tank Girl',
#  '9059': 'Tales from the Crypt: Demon Knight',
#  '193': 'Star Trek: Generations',
#  '25066': 'Tales from the Hood',
#  '46797': 'Tom & Viv',
#  '12122': 'Village of the Damned',
#  '11381': 'Tommy Boy',
#  '32636': 'Vanya on 42nd Street',
#  '36141': 'The Underneath',
#  '95963': 'The Walking Dead',
#  '1587': "What's Eating Gilbert Grape",
#  '9271': 'Virtuosity',
#  '2064': 'While You Were Sleeping',
#  '19855': 'The War',
#  '60855': 'Double Happiness',
#  '236': "Muriel's Wedding",
#  '48287': 'The Baby-Sitters Club',
#  '3049': 'Ace Ventura: Pet Detective',
#  '2759': 'The Adventures of Priscilla, Queen of the Desert',
#  '12635': 'Backbeat',
#  '10497': 'Bitter Moon',
#  '11382': 'Bullets Over Broadway',
#  '9331': 'Clear and Present Danger',
#  '10731': 'The Client',
#  '10464': 'Corrina, Corrina',
#  '34152': 'Crooklyn',
#  '9495': 'The Crow',
#  '29973': 'Cobb',
#  '888': 'The Flintstones',
#  '13': 'Forrest Gump',
#  '712': 'Four Weddings and a Funeral',
#  '16295': 'Higher Learning',
#  '48992': 'I Like It Like That',
#  '10879': 'I Love Trouble',
#  '10660': 'It Could Happen to You',
#  '10714': 'The Jungle Book',
#  '41647': 'Die Macht der Bilder: Leni Riefenstahl',
#  '8587': 'The Lion King',
#  '1689': 'Little Buddha',
#  '11596': 'New Nightmare',
#  '854': 'The Mask',
#  '9359': 'Maverick',
#  '23333': 'Mrs. Parker and the Vicious Circle',
#  '36593': 'The Naked Gun 33⅓: The Final Insult',
#  '12280': 'The Paper',
#  '2788': 'Reality Bites',
#  '10427': 'Red Rock West',
#  '11011': 'Ri¢hie Ri¢h',
#  '49803': 'Safe Passage',
#  '8987': 'The River Wild',
#  '1637': 'Speed',
#  '15128': 'Speechless',
#  '8831': 'Timecop',
#  '36955': 'True Lies',
#  '10449': 'When a Man Loves a Woman',
#  '10395': 'Wolf',
#  '12160': 'Wyatt Earp',
#  '40480': 'Bad Company',
#  '52038': 'A Man of No Importance',
#  '29444': 'S.F.W.',
#  '26352': 'A Low Down Dirty Shame',
#  '39953': 'Boys Life: Three Stories of Love, Lust, and Liberation',
#  '41580': 'Le colonel Chabert',
#  '315': 'Faster, Pussycat! Kill! Kill!',
#  '22067': "Jason's Lyric",
#  '18242': 'The Secret Adventures of Tom Thumb',
#  '11667': 'Street Fighter',
#  '32502': 'Coldblooded',
#  '267188': 'Desert Winds',
#  '28732': 'Fall Time',
#  '75555': 'The Fear',
#  '42981': 'Frank and Ollie',
#  '278939': 'Girl in the Cadillac',
#  '291731': 'Homage',
#  '226229': 'Mirage',
#  '203119': 'Open Season',
#  '172923': 'Dos Crímenes',
#  '316098': 'Brother Minister: The Assassination of Malcolm X',
#  '8011': 'Highlander III: The Sorcerer',
#  '171857': 'Federal Hill',
#  '2654': 'In the Mouth of Madness',
#  '18069': '8 Seconds',
#  '19092': 'Above the Rim',
#  '2758': 'Addams Family Values',
#  '38129': 'Martin Lawrence: You So Crazy',
#  '10436': 'The Age of Innocence',
#  '13595': 'Airheads',
#  '46094': 'The Air Up There',
#  '9409': 'Another Stakeout',
#  '11853': 'Bad Girls',
#  '16771': 'Barcelona',
#  '46924': 'Being Human',
#  '11041': 'The Beverly Hillbillies',
#  '306': 'Beverly Hills Cop III',
#  '14522': 'Black Beauty',
#  '26203': 'Blink',
#  '178': 'Blown Away',
#  '19819': 'Blue Chips',
#  '57834': 'Blue Sky',
#  '4722': 'Body Snatchers',
#  '18215': 'Boxing Helena',
#  '1607': 'A Bronx Tale',
#  '26391': 'Cabin Boy',
#  '117553': 'Calendar Girl',
#  '6075': "Carlito's Way",
#  '11310': "City Slickers II: The Legend of Curly's Gold",
#  '18658': 'Clean Slate',
#  '9350': 'Cliffhanger',
#  '9612': 'Coneheads',
#  '2124': 'Color of Night',
#  '26261': 'Cops & Robbersons',
#  '19176': 'The Cowboy Way',
#  '49299': 'Dangerous Game',
#  '11566': 'Dave',
#  '9571': 'Dazed and Confused',
#  '9739': 'Demolition Man',
#  '24257': 'The Endless Summer 2',
#  '34444': 'Even Cowgirls Get the Blues',
#  '26141': 'Fatal Instinct',
#  '10997': '霸王别姬',
#  '50463': 'The Favor',
#  '10443': 'Fearless',
#  '20239': 'Fear of a Black Hat',
#  '16297': 'With Honors',
#  '18551': 'Flesh and Bone',
#  '25440': "Widows' Peak",
#  '9024': 'For Love or Money',
#  '37233': 'The Firm',
#  '1634': 'Free Willy',
#  '13815': 'Fresh',
#  '5503': 'The Fugitive',
#  '35588': 'Geronimo: An American Legend',
#  '2087': 'The Getaway',
#  '41579': 'Getting Even with Dad',
#  '18620': 'Go Fish',
#  '41006': 'A Good Man in Africa',
#  '4916': 'Guilty as Sin',
#  '2019': 'Hard Target',
#  '31642': 'Heaven & Earth',
#  '9255': 'Hot Shots! Part Deux',
#  '26271': 'Live Nude Girls',
#  '10612': 'The Englishman Who Went Up a Hill But Came Down a Mountain',
#  '2259': 'The House of the Spirits',
#  '16097': 'House Party 3',
#  '11934': 'The Hudsucker Proxy',
#  '106143': "I'll Do Anything",
#  '12475': 'In the Army Now',
#  '9386': 'In the Line of Fire',
#  '7984': 'In the Name of the Father',
#  '59930': 'The Inkwell',
#  '15765': "What's Love Got to Do with It",
#  '31643': 'Jimmy Hollywood',
#  '6': 'Judgment Night',
#  '329': 'Jurassic Park',
#  '10909': 'Kalifornia',
#  '507': 'Killing Zoe',
#  '34024': 'King of the Hill',
#  '29918': 'Lassie',
#  '9593': 'Last Action Hero',
#  '42580': 'Life With Mikey',
#  '22317': 'Lightning Jack',
#  '1413': 'M. Butterfly',
#  '12121': 'Made in America',
#  '2246': 'Malice',
#  '10502': 'The Man without a Face',
#  '10440': 'Manhattan Murder Mystery',
#  '9516': 'Menace II Society',
#  '2320': 'Executive Decision',
#  '5879': '愛のコリーダ',
#  '83718': 'What Happened Was...',
#  '11971': 'Much Ado About Nothing',
#  '2625': 'Mr. Jones',
#  '31911': 'Mr. Wonderful',
#  '788': 'Mrs. Doubtfire',
#  '21450': 'Naked',
#  '11231': 'The Next Karate Kid',
#  '41588': 'The New Age',
#  '10447': 'No Escape',
#  '31586': 'North',
#  '9300': 'Orlando',
#  '9559': 'A Perfect World',
#  '9800': 'Philadelphia',
#  '713': 'The Piano',
#  '8291': 'Poetic Justice',
#  '18133': 'The Program',
#  '25557': 'The Puppet Masters',
#  '22588': 'Radioland Murders',
#  '10872': 'The Ref',
#  '1245': 'The Remains of the Day',
#  '11858': 'Renaissance Man',
#  '7007': 'Rising Sun',
#  '10467': 'The Road to Wellville',
#  '5550': 'RoboCop 3',
#  '8005': 'Robin Hood: Men in Tights',
#  '2088': 'Romeo Is Bleeding',
#  '10412': 'Romper Stomper',
#  '47889': 'Ruby in Paradise',
#  '14534': 'Rudy',
#  '56583': 'The Saint of Fort Washington',
#  '41878': 'Les Nuits Fauves',
#  '424': "Schindler's List",
#  '35233': 'The Scout',
#  '14291': 'Searching for Bobby Fischer',
#  '103413': 'Second Best',
#  '11236': 'The Secret Garden',
#  '11592': 'Serial Mom',
#  '8850': 'The Shadow',
#  '10445': 'Shadowlands',
#  '695': 'Short Cuts',
#  '43535': 'A Simple Twist of Fate',
#  '12519': 'Sirens',
#  '23210': 'Six Degrees of Separation',
#  '858': 'Sleepless in Seattle',
#  '867': 'Sliver',
#  '78': 'Blade Runner',
#  '13203': 'Son in Law',
#  '10442': 'So I Married an Axe Murderer',
#  '11074': 'Striking Distance',
#  '33367': 'Harem',
#  '9607': 'Super Mario Bros.',
#  '17585': 'Surviving the Game',
#  '9057': 'Terminal Velocity',
#  '20967': 'Thirty Two Short Films About Glenn Gould',
#  '10635': 'Threesome',
#  '9479': 'The Nightmare Before Christmas',
#  '10057': 'The Three Musketeers',
#  '11969': 'Tombstone',
#  '41590': 'Trial by Jury',
#  '319': 'True Romance',
#  '26408': 'The War Room',
#  '15139': 'The Pagemaster',
#  '161158': 'Paris, France',
#  '218473': 'The Beans of Egypt, Maine',
#  '85247': 'Killer',
#  '11446': 'Welcome to the Dollhouse',
#  '51980': 'Germinal',
#  '24405': 'Chasers',
#  '11655': 'Cronos',
#  '11800': 'Naked in New York',
#  '8223': 'Kika',
#  '14587': 'Bhaji on the Beach',
#  '31504': 'Little Big League',
#  '41653': 'Kådisbellan',
#  '53185': 'Wide Eyed and Legless',
#  '95743': 'Foreign Student',
#  '23637': 'Io speriamo che me la cavo',
#  '17600': 'Spanking the Monkey',
#  '10897': 'The Little Rascals',
#  '349394': 'À la mode',
#  '21352': 'Andre',
#  '68806': 'La scorta',
#  '37345': 'Princess Caraboo',
#  '32562': 'The Celluloid Closet',
#  '47507': 'Métisse',
#  '25403': 'Caro diario',
#  '124304': 'De eso no se habla',
#  '9066': 'The Brady Bunch Movie',
#  '771': 'Home Alone',
#  '251': 'Ghost',
#  '812': 'Aladdin',
#  '280': 'Terminator 2: Judgment Day',
#  '581': 'Dances with Wolves',
#  '80350': 'Tough and Deadly',
#  '268': 'Batman',
#  '274': 'The Silence of the Lambs',
#  '408': 'Snow White and the Seven Dwarfs',
#  '10020': 'Beauty and the Beast',
#  '10895': 'Pinocchio',
#  '114': 'Pretty Woman',
#  '41043': 'Окно в Париж',
#  '576': 'The Wild Bunch',
#  '15477': 'Love and a .45',
#  '59146': "The Wooden Man's Bride",
#  '124472': 'A Great Day in Harlem',
#  '30528': 'Bye Bye Love',
#  '7300': 'One Fine Day',
#  '10824': 'Candyman: Farewell to the Flesh',
#  '261246': 'Century',
#  '275': 'Fargo',
#  '25059': 'Homeward Bound II: Lost in San Francisco',
#  '11827': 'Heavy Metal',
#  '8766': 'Hellraiser: Bloodline',
#  '23570': 'The Pallbearer',
#  '47333': 'Jane Eyre',
#  '54850': 'Loaded',
#  '51242': 'Pane e cioccolata',
#  '10112': 'The Aristocats',
#  '4307': 'La flor de mi secreto',
#  '46029': 'Two Much',
#  '32308': 'Ed',
#  '88893': 'Schrei aus Stein',
#  '52873': 'Ma saison préférée',
#  '123505': 'A Modern Affair',
#  '340210': 'Condition Red',
#  '44281': 'Asfour Stah',
#  '28121': 'A Thin Line Between Love and Hate',
#  '12520': 'The Last Supper',
#  '1592': 'Primal Fear',
#  '166901': 'Rude',
#  '36447': 'Carried Away',
#  '19042': 'All Dogs Go to Heaven 2',
#  '38884': 'Land and Freedom',
#  '47449': 'Denise Calls Up',
#  '36259': 'Theodore Rex',
#  '41852': 'A Family Thing',
#  '40926': 'Frisk',
#  '9099': 'Sgt. Bilko',
#  '2021': 'Jack & Sarah',
#  '61752': 'Girl 6',
#  '10988': 'Diabolique',
#  '11479': 'Un indien dans la ville',
#  '398959': 'Roula - Dunkle Geheimnisse',
#  '287305': 'Peanuts – Die Bank zahlt alles',
#  '339428': 'Happy Weekend',
#  '12652': 'Nelly & Monsieur Arnaud',
#  '10684': 'Courage Under Fire',
#  '954': 'Mission: Impossible',
#  '68445': 'Á köldum klaka',
#  '18989': 'Moll Flanders',
#  '10801': 'Das Superweib',
#  '54285': '삼공일 삼공이',
#  '8840': 'DragonHeart',
#  '278978': 'Und keiner weint mir nach',
#  '124625': "My Mother's Courage",
#  '11107': 'Eddie',
#  '16417': 'Yankee Zulu',
#  '70934': "Billy's Holiday",
#  '10363': 'Plein soleil',
#  '161070': 'August',
#  '10539': 'James and the Giant Peach',
#  '10543': 'Fear',
#  '18414': 'Kids in the Hall: Brain Candy',
#  '47502': 'Faithful',
#  '11902': 'Podzemlje',
#  '27098': 'Lust och fägring stor',
#  '25087': 'Bloodsport II',
#  '5801': 'পথের পাঁচালী',
#  '896': 'অপুর সংসার',
#  '3065': 'Mystery Science Theater 3000: The Movie',
#  '318177': 'Tarantella',
#  '2300': 'Space Jam',
#  '8069': 'Barbarella',
#  '288173': 'Hostile Intentions',
#  '187851': 'They Bite',
#  '27768': 'Some Folks Call It a Sling Blade',
#  '221917': 'The Run of the Country',
#  '8072': 'Alphaville, une étrange aventure de Lemmy Caution',
#  '35797': 'Coup de torchon',
#  '88030': 'Tigrero: A Film That Was Never Made',
#  '185191': "L'oeil de Vichy",
#  '83857': 'Windows',
#  '33245': "It's My Party",
#  '124460': 'Country Life',
#  '27281': 'Operation Dumbo Drop',
#  '105045': 'Das Versprechen',
#  '40001': 'Mrs. Winterbourne',
#  '29621': 'Solo',
#  '117730': 'Etz Hadomim Tafus',
#  '20762': 'The Substitute',
#  '37144': 'True Crime',
#  '48260': 'Butterfly Kiss',
#  '12656': 'Feeling Minnesota',
#  '38867': 'Delta of Venus',
#  '277270': 'To Cross the Rubicon',
#  '25969': 'Angus',
#  '44103': 'Daens',
#  '753': 'Faces',
#  '43634': 'Boys',
#  '9103': 'The Quest',
#  '90214': 'Cosi',
#  '29649': 'Sunset Park',
#  '10990': 'Mulholland Falls',
#  '8866': 'The Truth About Cats & Dogs',
#  '12233': 'Oliver & Company',
#  '23449': 'Celtic Pride',
#  '36355': 'Flipper',
#  '37667': 'Captives',
#  '90148': 'Of Love and Shadows',
#  '922': 'Dead Man',
#  '11876': 'Le Hussard sur le toit',
#  '52633': 'Switchblade Sisters',
#  '62364': 'Boca a boca',
#  '11687': 'Les visiteurs',
#  '9304': 'Multiplicity',
#  '73183': 'The Haunted World of Edward D. Wood, Jr.',
#  '131232': 'Due Amici',
#  '9100': 'The Craft',
#  '20759': 'The Great White Hype',
#  '46063': 'Last Dance',
#  '365371': 'War Stories Our Mother Never Told Us',
#  '32513': 'Cold Comfort Farm',
#  '40651': 'Institute Benjamenta, or This Dream People Call Human Life',
#  '36915': "Heaven's Prisoners",
#  '40507': 'Original Gangstas',
#  '9802': 'The Rock',
#  '25697': 'Getting Away with Murder',
#  '21588': 'Dellamorte Dellamore',
#  '664': 'Twister',
#  '11867': 'Barb Wire',
#  '47119': 'Le garçu',
#  '314352': 'Honigmond',
#  '9323': 'GHOST IN THE SHELL',
#  '10280': 'Thinner',
#  '10535': 'Spy Hard',
#  '124613': 'Brothers in Trouble',
#  '532': 'A Close Shave',
#  '26744': 'Force of Evil',
#  '16299': 'The Stupids',
#  '10547': 'The Arrival',
#  '245268': 'The Man from Down Under',
#  '935': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  '55613': 'Careful',
#  '215107': 'Vermont Is for Lovers',
#  '41007': 'A Month by the Lake',
#  '35645': 'Gold Diggers: The Secret of Bear Mountain',
#  '110465': 'Kim',
#  '255546': 'Carmen Miranda: Bananas Is My Business',
#  '40751': '東邪西毒',
#  '275096': 'Khomreh',
#  '85778': 'Maya Lin: A Strong Clear Vision',
#  '11101': 'Stalingrad',
#  '9826': 'The Phantom',
#  '9879': 'Striptease',
#  '63564': 'The Last of the High Kings',
#  '22621': 'Heavy',
#  '7095': 'Jack',
#  '26890': 'I Shot Andy Warhol',
#  '46732': 'The Grass Harp',
#  '124633': 'Tuđa Amerika',
#  '202425': 'La vie est belle',
#  '196940': 'Quartier Mozart',
#  '77771': 'Touki-Bouki',
#  '181083': 'Wend Kuuni',
#  '41225': 'Histoires extraordinaires',
#  '188589': 'Babyfever',
#  '87190': "Pharaoh's  Army",
#  '627': 'Trainspotting',
#  '32872': 'Til There Was You',
#  '602': 'Independence Day',
#  '14553': 'Stealing Beauty',
#  '9566': 'The Fan',
#  '10545': 'The Hunchback of Notre Dame',
#  '9894': 'The Cable Guy',
#  '11543': 'Kingpin',
#  '9268': 'Eraser',
#  '52059': 'The Gate of Heavenly Peace',
#  '9327': 'The Nutty Professor',
#  '123763': 'Yo, la peor de todas',
#  '81949': 'Un été inoubliable',
#  '42005': 'Hol volt, hol nem volt',
#  '124306': "En compagnie d'Antonin Artaud",
#  '183955': 'Sibak',
#  '44535': 'Somebody to Love',
#  '44495': 'A Very Natural Thing',
#  '78285': 'La vieille qui marchait dans la mer',
#  '11228': 'Daylight',
#  '10779': 'The Frighteners',
#  '26748': 'Lone Star',
#  '38223': 'Harriet the Spy',
#  '9294': 'Phenomenon',
#  '49963': 'Walking and Talking',
#  '11363': "She's the One",
#  '1645': 'A Time to Kill',
#  '31546': 'American Buffalo',
#  '77056': 'Les Rendez-vous de Paris',
#  '36344': 'Alaska',
#  '18550': 'Fled',
#  '11511': 'Kazaam',
#  '172198': 'Bűvös vadász',
#  '34170': 'Larger Than Life',
#  '281085': 'A Boy Called Hate',
#  '109478': 'Power 98',
#  '124645': 'Two Deaths',
#  '12606': 'A Very Brady Sequel',
#  '69895': 'Stefano Quantestorie',
#  '35206': 'La mort en ce jardin',
#  '151489': 'Hedd Wyn',
#  '4837': 'La Collectionneuse',
#  '12632': 'Kaspar Hauser',
#  '9098': 'Echte Kerle',
#  '282919': 'Diebinnen',
#  '124614': 'O Convento',
#  '18975': 'The Adventures of Pinocchio',
#  '11962': "Joe's Apartment",
#  '2925': 'The First Wives Club',
#  '28628': 'Stonewall',
#  '3595': 'Ransom',
#  '9308': 'High School High',
#  '92381': 'Phat Beach',
#  '18555': 'Foxfire',
#  '12123': 'Chain Reaction',
#  '10830': 'Matilda',
#  '3573': 'Emma',
#  '10546': 'The Crow: City of Angels',
#  '18862': 'House Arrest',
#  '31417': 'Les Yeux sans visage',
#  '9431': 'Bordello of Blood',
#  '124619': 'Lotto Land',
#  '297645': 'The Story of Xinghua',
#  '48144': '天國逆子',
#  '46986': 'Flirt',
#  '144982': 'The Big Squeeze',
#  '47907': 'The Spitfire Grill',
#  '10061': 'Escape from L.A.',
#  '36266': 'Xích lô',
#  '549': 'Basquiat',
#  '10478': 'Tin Cup',
#  '66634': 'Dingo',
#  '116690': '楢山節考',
#  '213917': 'Un week-end sur deux',
#  '145925': 'Mille bolle blu',
#  '100914': 'Wuya yu maque',
#  '238': 'The Godfather',
#  '159': 'Der bewegte Mann',
#  '11134': '警察故事 III：超級警察',
#  '88224': 'Manny & Lo',
#  '132641': 'Tsuma',
#  '42758': 'Small Faces',
#  '9303': 'Bound',
#  '23945': 'Carpool',
#  '37820': 'Death in Brunswick',
#  '22479': 'Kansas City',
#  '9054': "Gone Fishin'",
#  '241058': "Lover's Knot",
#  '11985': '愛情萬歲',
#  '10232': 'Schatten der Engel',
#  '59569': 'Killer: A Journal of Murder',
#  '410921': 'Nothing to Lose',
#  '38955': '超级计划',
#  '110513': 'Girls Town',
#  '114089': 'Bye-Bye',
#  '11015': 'The Relic',
#  '9306': 'The Island of Dr. Moreau',
#  '12559': 'First Kid',
#  '58770': 'The Trigger Effect',
#  '124851': 'Sweet Nothing',
#  '3587': 'Bogus',
#  '10723': 'Bulletproof',
#  '56077': 'Talk of Angels',
#  '19004': 'The Land Before Time III: The Time of the Great Giving',
#  '101230': '06',
#  '253632': 'Baton Rouge',
#  '10987': 'Halloween: The Curse of Michael Myers',
#  '44705': 'Twelfth Night',
#  '20318': 'Mother Night',
#  '43596': 'Liebelei',
#  '79782': 'Wenecja',
#  '26933': 'Les Roseaux Sauvages',
#  '27854': 'For Whom the Bell Tolls',
#  '981': 'The Philadelphia Story',
#  '872': "Singin' in the Rain",
#  '2769': 'An American in Paris',
#  '13320': 'Funny Face',
#  '164': "Breakfast at Tiffany's",
#  '426': 'Vertigo',
#  '567': 'Rear Window',
#  '3078': 'It Happened One Night',
#  '13528': 'Gaslight',
#  '28288': 'The Gay Divorcee',
#  '213': 'North by Northwest',
#  '284': 'The Apartment',
#  '239': 'Some Like It Hot',
#  '4808': 'Charade',
#  '289': 'Casablanca',
#  '963': 'The Maltese Falcon',
#  '11113': 'My Fair Lady',
#  '6620': 'Sabrina',
#  '804': 'Roman Holiday',
#  '26531': 'The Little Princess',
#  '909': 'Meet Me in St. Louis',
#  '630': 'The Wizard of Oz',
#  '770': 'Gone with the Wind',
#  '31044': 'My Favorite Year',
#  '599': 'Sunset Boulevard',
#  '15': 'Citizen Kane',
#  '62': '2001: A Space Odyssey',
#  '121357': 'Golden Earrings',
#  '705': 'All About Eve',
#  '22490': 'The Women',
#  '223': 'Rebecca',
#  '25670': 'Foreign Correspondent',
#  '303': 'Notorious',
#  '4174': 'Spellbound',
#  '8356': 'An Affair to Remember',
#  '381': 'To Catch a Thief',
#  '20758': 'Father of the Bride',
#  '29376': 'The Band Wagon',
#  '1859': 'Ninotchka',
#  '18299': 'Love in the Afternoon',
#  '17281': 'Gigi',
#  '64382': 'The Reluctant Debutante',
#  '10907': 'The Adventures of Robin Hood',
#  '32093': 'The Mark of Zorro',
#  '1939': 'Laura',
#  '22292': 'The Ghost and Mrs. Muir',
#  '3598': 'Lost Horizon',
#  '3080': 'Top Hat',
#  '198': 'To Be or Not to Be',
#  '13562': 'My Man Godfrey',
#  '1712': 'Giant',
#  '220': 'East of Eden',
#  '3529': 'The Thin Man',
#  '3085': 'His Girl Friday',
#  '2897': 'Around the World in Eighty Days',
#  '1585': "It's a Wonderful Life",
#  '3083': 'Mr. Smith Goes to Washington',
#  '900': 'Bringing Up Baby',
#  '43795': 'Penny Serenade',
#  '85638': 'The Scarlet Letter',
#  '50001': 'Lady of Burlesque',
#  '43905': 'Of Human Bondage',
#  '22688': 'Angel on My Shoulder',
#  '23114': 'Little Lord Fauntleroy',
#  '26378': 'They Made Me a Criminal',
#  '40206': 'The Inspector General',
#  '22356': 'Angel and the Badman',
#  '260': 'The 39 Steps',
#  '43488': 'A Walk in the Sun',
#  '22613': 'The Outlaw',
#  '10331': 'Night of the Living Dead',
#  '488': 'The African Queen',
#  '22733': 'Beat the Devil',
#  '261': 'Cat on a Hot Tin Roof',
#  '57575': 'The Last Time I Saw Paris',
#  '32574': 'Meet John Doe',
#  '22657': 'Algiers',
#  '76464': 'Something to Sing About',
#  '22649': 'A Farewell to Arms',
#  '176841': 'Moonlight Murder',
#  '125587': 'Nothing Personal',
#  '39448': 'Huang jia shi jie',
#  '52855': 'Dangerous Ground',
#  '39940': 'Picnic',
#  '172868': 'Madagascar Skin',
#  '85328': 'The Pompatus of Love',
#  '124632': 'Small Wonders',
#  '11076': 'Fly Away Home',
#  '63945': 'Bliss',
#  '58985': 'Grace of My Heart',
#  '890': 'Schlafes Bruder',
#  '10861': 'Maximum Risk',
#  '1770': 'Michael Collins',
#  '44465': "The Rich Man's Wife",
#  '2033': 'Infinity',
#  '18203': 'Big Night',
#  '9333': 'Last Man Standing',
#  '47260': 'Caught',
#  '9400': 'Set It Off',
#  '9401': '2 Days in the Valley',
#  '12241': 'Curdled',
#  '25739': "L'associé",
#  '161806': "Ed's Next Move",
#  '11306': 'Extreme Measures',
#  '9625': 'The Glimmer Man',
#  '10680': 'D3: The Mighty Ducks',
#  '6346': 'The Chamber',
#  '18660': 'The Apple Dumpling Gang',
#  '35115': 'Davy Crockett, King of the Wild Frontier',
#  '14821': 'Escape to Witch Mountain',
#  '14136': 'The Love Bug',
#  '10869': 'Herbie Rides Again',
#  '22660': 'Old Yeller',
#  '19186': 'The Parent Trap',
#  '31102': 'Pollyanna',
#  '6878': 'Homeward Bound: The Incredible Journey',
#  '15944': 'The Shaggy Dog',
#  '18444': 'Swiss Family Robinson',
#  '20723': 'That Darn Cat!',
#  '173': '20,000 Leagues Under the Sea',
#  '864': 'Cool Runnings',
#  '24795': 'Angels in the Outfield',
#  '11224': 'Cinderella',
#  '81310': 'Winnie the Pooh and the Blustery Day',
#  '15947': 'The Three Caballeros',
#  '9078': 'The Sword in the Stone',
#  '29682': 'So Dear to My Heart',
#  '8367': 'Robin Hood: Prince of Thieves',
#  '433': 'Mary Poppins',
#  ...}

# %%
# create users input
users = interactions[['userId']].drop_duplicates().reset_index(drop = True)

# %% [markdown]
# # 3. Model
#
# Let's define our baseline popularity recommender BaselineRecommender - top rated titles based on average rating with possibility to get by any group(s)

# %% [markdown]
# The pipeline will be similar to most python ML modules -- it will have two methods in the end: fit() and recommend()
# 1. The logic of fit() as follow:
# - Initiate recommendation based on median rating from all observations recomm_common;
# - Prepare list of interacted items by users
# - If we set groups - we get recommendations i.e. calculate movie ratings by groups:
#     - If we get NaN, we fill with base recommendations
#     - If we get less than required number of candidates, we populate from base recommendations
#
# 2. The logic of recommend():
# - Return base recommendations if users data is not set;
# - In case of category wise requirement -- we get results of our fit

# %% [markdown]
# ## 3.1. Fit

# %%
# first, we define how many candidates we want to get
MAX_CANDIDATES = 20
ITEM_COLUMN = 'movieId'
USER_COLUMN = 'userId'

# %%
# then, we extract top 20 movies by aggregating movies and averaging rating column across all users
base_recommendations = compute_popularity(interactions_filtered, ITEM_COLUMN, MAX_CANDIDATES)
base_recommendations
# Out:
# array(['74727', '128846', '702', '127728', '65216', '43267', '8675',
#        '80717', '86817', '8699', '872', '27724', '26791', '876', '64278',
#        '301', '59392', '3021', '3112', '1933'], dtype=object)

# %% [markdown]
# Thus, we got 20 films with highest average rating
#
# Now, as we discussed earlier, in movies recommendations there is no need to recommend the same film which user has already watched. Let's implement it as well

# %%
# we get all interacted items for each user and save it in dictionary {'userId': [items list]}
known_items = interactions_filtered.groupby(USER_COLUMN)[ITEM_COLUMN].apply(list).to_dict()
len(known_items)
# Out:
# 671

# %%
# let's check it for one userId = 1
known_items[1]
# Out:
# ['1371', '1405', '2105', '2193', '2294', '2455']

# %% [markdown]
# Now we have all necessary components: base recommendations without groups with possibility to filter already watched items
#
# Also, if we want to get recommendations based on some user groups we can easily do the same with groupby() method and same approach

# %%
# lets add artifical binary group to check BaselineRecommender
group = [np.random.random_integers(2) for x in range(len(users))]
users['group'] = group

# %%
users.groupby('group').count()
# Out:
#        userId
# group
# 1         344
# 2         327

# %%
data = pd.merge(interactions_filtered, users, how='left', on = USER_COLUMN)
group_recommendations = data.groupby('group').apply(compute_popularity, ITEM_COLUMN, MAX_CANDIDATES)
group_recommendations.head()
# Out:
# group
# 1    [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 2    [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# dtype: object

# %% [markdown]
# In the output we have two rows with a list of film ids for each binary group
#
# Next, we have to implement recommned() method which will use

# %% [markdown]
# ## 3. 2. Recommend

# %%
# if we do not have groups, then it means we give the same recommendations for all users i.e. base_recommendations
recs = list(islice(cycle([base_recommendations]), len(users['userId'])))
users['rekkos'] = recs
users.head()
# Out:
#    userId  group                                             rekkos
# 0       1      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 1       2      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 2       3      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 3       4      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 4       5      1  [74727, 128846, 702, 127728, 65216, 43267, 867...

# %%
# and let's have an example with groups we created earlier
group_recommendations = group_recommendations.reset_index()
group_rekkos = pd.merge(users, group_recommendations, how = 'left', on = 'group')
group_rekkos.rename(columns = {0: 'rekkos'}, inplace = True)
group_rekkos.head()
# Out:
#    userId  group                                             rekkos  \
# 0       1      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 1       2      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 2       3      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 3       4      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 4       5      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
#
#                                               rekkos
# 0  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 1  [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# 2  [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# 3  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 4  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...

# %% [markdown]
# We got our groupwise recommendations from 3.1. part and just joined them by group of users are assigned to

# %% [markdown]
# ## 3.3. Wrap everything into pretty functions

# %% [markdown]
# ### 3.3.1 Fit part

# %%
def fit(
    data: pd.DataFrame,
    item_col: str, groups: list = None,
    max_candidates: int = 20
    ):
    """
    function runs all pipeline to generate recommendations based on given group
    :data: dataframe of interactions
    :item_col: item column name
    :groups: optional, list of groups column names to get recommendations
    :max_candidates: number of recommendations to return
    """
    
    if groups is not None:
        recommendations = data.groupby(groups).apply(compute_popularity, item_col, max_candidates)
    else:
        recommendations = compute_popularity(data, item_col, max_candidates)

    return recommendations

# %%
# check base
fit(data, item_col=ITEM_COLUMN)
# Out:
# array(['74727', '128846', '702', '127728', '65216', '43267', '8675',
#        '80717', '86817', '8699', '872', '27724', '26791', '876', '64278',
#        '301', '59392', '3021', '3112', '1933'], dtype=object)

# %%
# check group-wise
fit(data, item_col=ITEM_COLUMN, groups=['group'])
# Out:
# group
# 1    [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 2    [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# dtype: object

# %% [markdown]
# ### 3.3.2 Recommend part

# %%
def recommend(
    users: pd.DataFrame,
    recommendations: pd.DataFrame,
    groups: list = None,
    K: int = 10):
    """
    recommends items for a given list of users
    :users: series / list of users to recommend
    :recommendations: output of fit() function
    :groups: optional, list of groups column names to get recommendations
    :K: number of items to recommend (not always we want to show dozens of items instantly)
    """
    if groups is not None:
        output = pd.merge(users, recommendations.reset_index(), how = 'left', on = 'group')

    else:
        output = users.copy(deep = True)
        recs = list(islice(cycle([recommendations]), len(users['userId'])))
        output['rekkos'] = recs

    return output

# %%
# check
recs = fit(data, item_col=ITEM_COLUMN)
check_recs = recommend(users[['userId', 'group']], recs)
check_recs.head()
# Out:
#    userId  group                                             rekkos
# 0       1      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 1       2      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 2       3      2  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 3       4      1  [74727, 128846, 702, 127728, 65216, 43267, 867...
# 4       5      1  [74727, 128846, 702, 127728, 65216, 43267, 867...

# %%
# check group-wise
recs = fit(data, item_col=ITEM_COLUMN, groups = ['group'])
check_recs = recommend(users[['userId', 'group']], recs, ['group'])
check_recs.head()
# Out:
#    userId  group                                                  0
# 0       1      1  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 1       2      2  [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# 2       3      2  [702, 667, 91690, 3966, 2287, 1939, 1859, 4928...
# 3       4      1  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...
# 4       5      1  [850, 40226, 86817, 2984, 26326, 64499, 5765, ...

# %% [markdown]
# Congrats! Your first basic recommender system is ready!!

# %% [markdown]
# # TODO
# - Add filtration of watched items to pipeline
# - Also, consider cases when you fitler watched ones and you have less items in recommendations than required i.e. number of recommendations < MAX_CANDIDATES
# - Add name mapper to `movieId`

# %% [markdown]
# # So, What is Next?

# %% [markdown]
# Well, in this section we discussed how basic recommendations based on heuristic can be done
# - We took top-rated films and recommended to users
# - Added filter to remove already watched films
# - Wrapped all steps into functions
#
#
# In the next chapter we will talk about a bit relatively more advanced techniques like Content-Based / Collaborative Filtering
